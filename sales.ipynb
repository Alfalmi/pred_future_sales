# %%
import os
import joblib
# Core
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(style='darkgrid', font_scale=1.4)
from imblearn.over_sampling import SMOTE
import itertools
import warnings
warnings.filterwarnings('ignore')
import plotly.express as px
import time

# Sklearn
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV, StratifiedKFold, cross_val_score
from sklearn.metrics import accuracy_score, confusion_matrix, recall_score, precision_score, f1_score
# from sklearn.metrics import roc_auc_score, plot_confusion_matrix, plot_roc_curve, roc_curve
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder, LabelEncoder
from sklearn.feature_selection import mutual_info_classif
from sklearn.decomposition import PCA
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
# import eli5
# from eli5.sklearn import PermutationImportance
from sklearn.utils import resample

# Models
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from sklearn.naive_bayes import GaussianNB

# Get path from training and test dataset

curr_path = os.getcwd()
dataset_src = os.path.join(curr_path, 'dataset')

sales_train = pd.read_csv(os.path.join(dataset_src, 'sales_train.csv'), parse_dates=["date"])
test = pd.read_csv(os.path.join(dataset_src, 'test.csv'), index_col=['ID'])
item_categories = pd.read_csv(os.path.join(dataset_src, 'item_categories.csv'))
items = pd.read_csv(os.path.join(dataset_src, 'items.csv'))
shops = pd.read_csv(os.path.join(dataset_src, 'shops.csv'))
sample_submission = pd.read_csv(os.path.join(dataset_src, 'sample_submission.csv'))

# %%
sales_train.groupby('item_id')['item_cnt_day'].sum()

# %%
test

# %%
print(sales_train.columns)
print(test.columns)
print('number of features', len(test.columns))

# %%
print(len(sales_train), 'records for the training dataset.')
print(len(test), 'records for the testing dataset. ')

# %%
total_sales = sales_train.item_cnt_day.sum()
total_shops = len(sales_train.shop_id)

print( total_sales, 'sales.')
print( total_shops, 'shops.')

# %%
plt.hist(sales_train.item_cnt_day)

# %%
# Feature exploration

list_features = sales_train.columns
print('They are',len(list_features),'features in the dataset.')
print('----------------')
for f in list_features:
    print('feature:', f, '|| Type:', type(sales_train[f][0]), '|| Example:', sales_train[f][0], '|| number of unique values', len(sales_train[f].unique()) )

# %%
len(items['item_id'].unique())

# %%
item_categories.head(50)

# %%
item_categories

# %%
item_categories['category']=np.nan
item_categories['dept']=np.nan
item_categories['category']=item_categories['item_category_name'].apply(lambda x: x.split('-')[0])
item_categories['dept']=item_categories['item_category_name'].apply(lambda x: ''.join(x.split('-')[1:]))

    

    
item_categories

# %%
data = items.merge(item_categories)
data.tail(50).sort_values(by='item_id')

# %%
items.tail(50).sort_values(by='item_id')

# %%
data = sales_train.merge(data)

# %%
data = data.merge(shops)

# %%
data.head()

# %%
data

# %%
quantitative = [f for f in data.columns if data.dtypes[f] != 'object']

qualitative = [f for f in data.columns if data.dtypes[f] == 'object']

# %%
quantitative

# %%
qualitative

# %%
print(data.columns)
print('number of features', len(data.columns))

# %%
print(data.isnull().sum())

# %%
data[['dept']].value_counts()

# %%
for x in data.groupby(['category']):
    for i in x:
        print(i)

# %%
data[['date_block_num', 'item_cnt_day']].sort_values(by='date_block_num')

# %%
data.groupby(['date_block_num']).item_cnt_day.sum()

# %%
item_cnt_month =  data[['date_block_num', 'item_cnt_day']].sort_values(by='date_block_num')

item_cnt_month.groupby(['date_block_num']).sum()
# for i in item_cnt_month:
#     print(i)

# %%
item_cnt_month =  data[['date_block_num', 'item_cnt_day']].groupby(['date_block_num']).sum().sort_values(by='date_block_num')

for i in range(1, len(item_cnt_month)):
    print(item_cnt_month[i-1:i], i-1)
    
# for i in item_cnt_month:
#     print(i)

# %%
data[data['date_block_num'] == 0]

# %%
data[data['date_block_num'].isin([0, 1])]

# %%
date.loc[date['date_block_num'] < 1, 'item_cnt_day']
# Out:
# 0         1.0
# 1         1.0
# 2        -1.0
# 3         1.0
# 4         1.0
#          ...
# 115685    1.0
# 115686    1.0
# 115687    2.0
# 115688    1.0
# 115689    1.0
# Name: item_cnt_day, Length: 115690, dtype: float64

# %%
data.plot.scatter(x='date_block_num',
                  y='item_cnt_day',
                  alpha=0.5)

# %%
[x for x in dir(data.plot) if not x.startswith("_")]

# %%
data.plot.box()

# %%
G = pd.read_csv(os.path.join(dataset_src, 'sales_train.csv'))
P = pd.read_csv(os.path.join(dataset_src, 'sales_train.csv'), index_col=0, parse_dates=True)

# %%
P['item_cnt_month'] = abs(P['item_cnt_day'] * 30)
P

# %%
G

# %%
P.rename(columns=str.lower)

# %%
# print(P['item_cnt_day'].mean() * P['date_block_num'].value_counts())
P['date_block_num'].describe()

# %%
data[data['date_block_num'] == 0].describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 data[data['date_block_num'] == 0].describe()
#
# NameError: name 'data' is not defined

# %%
data[data['date_block_num'] == 0].agg({'item_price': ['min', 'max', 'median', 'skew'],
                                       'item_cnt_day': ['min', 'max', 'median', 'mean']})

# %%
item_cnt_month = P.groupby('date_block_num')['item_cnt_day'].sum()

# %%
P.iloc[9:25, 2:5]

# %%
P.iloc[0:3, 3] = "anonymous"
P

# %%
P.pivot_table(values="item_cnt_day", index="date", columns="date_block_num", aggfunc="mean")

# %%
sales_train_ = sales_train.sort_values(by='item_id')

# %%
sales_train_.concat(test.sort_values(by='item_id'))

# %%
In [53]: result = pd.merge(left, right, on='B', how='outer', validate="one_to_one")one_to_many

# %%
In [63]: pd.merge(df1, df2, on='col1', how='outer', indicator='indicator_column')

# %%
sales_train.join(test, on='item_id')

# %%
# New feature - Group

date =  sales_train[['date', 'date_block_num', 'item_id', 'item_cnt_day', 'shop_id']]
date['day'] = date['date'].apply(lambda x: x.split('.')[0]).astype(int)
date['month'] = date['date'].apply(lambda x: x.split('.')[1]).astype(int)
date['year'] = date['date'].apply(lambda x: x.split('.')[2]).astype(int)

date.tail(50)
# Out:
#                date  date_block_num  item_id  item_cnt_day  shop_id  day  \
# 2935799  13.10.2015              33     7524           1.0       25   13
# 2935800  08.10.2015              33     7529           1.0       25    8
# 2935801  29.10.2015              33     7531           1.0       25   29
# 2935802  19.10.2015              33     7583           1.0       25   19
# 2935803  22.10.2015              33     7590           1.0       25   22
# 2935804  29.10.2015              33     7610           1.0       25   29
# 2935805  19.10.2015              33     7612           1.0       25   19
# 2935806  11.10.2015              33     7615           1.0       25   11
# 2935807  11.10.2015              33     7624           1.0       25   11
# 2935808  19.10.2015              33     7627           1.0       25   19
# 2935809  26.10.2015              33     7493           1.0       25   26
# 2935810  16.10.2015              33     7628           1.0       25   16
# 2935811  22.10.2015              33     7635           1.0       25   22
# 2935812  30.10.2015              33     7638           1.0       25   30
# 2935813  01.10.2015              33     7640           1.0       25    1
# 2935814  05.10.2015              33     7780           1.0       25    5
# 2935815  24.10.2015              33     7231           1.0       25   24
# 2935816  19.10.2015              33     7780           1.0       25   19
# 2935817  23.10.2015              33     7780           2.0       25   23
# 2935818  31.10.2015              33     7780           1.0       25   31
# 2935819  16.10.2015              33     7789           1.0       25   16
# 2935820  22.10.2015              33     7790           1.0       25   22
# 2935821  22.10.2015              33     7791           1.0       25   22
# 2935822  17.10.2015              33     7632           1.0       25   17
# 2935823  26.10.2015              33     7487           1.0       25   26
# 2935824  14.10.2015              33     7029           1.0       25   14
# 2935825  23.10.2015              33     7460           1.0       25   23
# 2935826  04.10.2015              33     7233           1.0       25    4
# 2935827  18.10.2015              33     7308           1.0       25   18
# 2935828  21.10.2015              33     7233           1.0       25   21
# 2935829  03.10.2015              33     7233           1.0       25    3
# 2935830  11.10.2015              33     7286           1.0       25   11
# 2935831  22.10.2015              33     7187           1.0       25   22
# 2935832  26.10.2015              33     7484           1.0       25   26
# 2935833  22.10.2015              33     7308           1.0       25   22
# 2935834  29.10.2015              33     7235           1.0       25   29
# 2935835  18.10.2015              33     7327           1.0       25   18
# 2935836  22.10.2015              33     7327           1.0       25   22
# 2935837  24.10.2015              33     7328           1.0       25   24
# 2935838  17.10.2015              33     7338           1.0       25   17
# 2935839  24.10.2015              33     7315           1.0       25   24
# 2935840  31.10.2015              33     7409           1.0       25   31
# 2935841  11.10.2015              33     7393           1.0       25   11
# 2935842  10.10.2015              33     7384           1.0       25   10
# 2935843  09.10.2015              33     7409           1.0       25    9
# 2935844  10.10.2015              33     7409           1.0       25   10
# 2935845  09.10.2015              33     7460           1.0       25    9
# 2935846  14.10.2015              33     7459           1.0       25   14
# 2935847  22.10.2015              33     7440           1.0       25   22
# 2935848  03.10.2015              33     7460           1.0       25    3
#
#          month  year
# 2935799     10  2015
# 2935800     10  2015
# 2935801     10  2015
# 2935802     10  2015
# 2935803     10  2015
# 2935804     10  2015
# 2935805     10  2015
# 2935806     10  2015
# 2935807     10  2015
# 2935808     10  2015
# 2935809     10  2015
# 2935810     10  2015
# 2935811     10  2015
# 2935812     10  2015
# 2935813     10  2015
# 2935814     10  2015
# 2935815     10  2015
# 2935816     10  2015
# 2935817     10  2015
# 2935818     10  2015
# 2935819     10  2015
# 2935820     10  2015
# 2935821     10  2015
# 2935822     10  2015
# 2935823     10  2015
# 2935824     10  2015
# 2935825     10  2015
# 2935826     10  2015
# 2935827     10  2015
# 2935828     10  2015
# 2935829     10  2015
# 2935830     10  2015
# 2935831     10  2015
# 2935832     10  2015
# 2935833     10  2015
# 2935834     10  2015
# 2935835     10  2015
# 2935836     10  2015
# 2935837     10  2015
# 2935838     10  2015
# 2935839     10  2015
# 2935840     10  2015
# 2935841     10  2015
# 2935842     10  2015
# 2935843     10  2015
# 2935844     10  2015
# 2935845     10  2015
# 2935846     10  2015
# 2935847     10  2015
# 2935848     10  2015

# %%
item_cnt_month = date.groupby(['year', 'month'])['item_cnt_day'].sum()
item_cnt_month.to_frame()
# data_ = pd.merge(date, item_cnt_month, on='month')
# data_
# Out:
#             item_cnt_day
# year month
# 2013 1          131479.0
#      2          128090.0
#      3          147142.0
#      4          107190.0
#      5          106970.0
#      6          125381.0
#      7          116966.0
#      8          125291.0
#      9          133332.0
#      10         127541.0
#      11         130009.0
#      12         183342.0
# 2014 1          116899.0
#      2          109687.0
#      3          115297.0
#      4           96556.0
#      5           97790.0
#      6           97429.0
#      7           91280.0
#      8          102721.0
#      9           99208.0
#      10         107422.0
#      11         117845.0
#      12         168755.0
# 2015 1          110971.0
#      2           84198.0
#      3           82014.0
#      4           77827.0
#      5           72295.0
#      6           64114.0
#      7           63187.0
#      8           66079.0
#      9           72843.0
#      10          71056.0

# %%
item_cnt_month = date.groupby(['year', 'month'])['item_cnt_day'].sum()

# %%
date[date['date_block_num'] == item_cnt_month['month']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/datascience-master/.venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:160, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index_class_helper.pxi:70, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'month'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 date[date['date_block_num'] == item_cnt_month['month']]
#
# File ~/datascience-master/.venv/lib/python3.10/site-packages/pandas/core/series.py:1040, in Series.__getitem__(self, key)
#    1037     return self._values[key]
#    1039 elif key_is_scalar:
# -> 1040     return self._get_value(key)
#    1042 # Convert generator to list before going through hashable part
#    1043 # (We will iterate through the generator there to check for slices)
#    1044 if is_iterator(key):
#
# File ~/datascience-master/.venv/lib/python3.10/site-packages/pandas/core/series.py:1156, in Series._get_value(self, label, takeable)
#    1153     return self._values[label]
#    1155 # Similar to Index.get_value, but we do not fall back to positional
# -> 1156 loc = self.index.get_loc(label)
#    1158 if is_integer(loc):
#    1159     return self._values[loc]
#
# File ~/datascience-master/.venv/lib/python3.10/site-packages/pandas/core/indexes/multi.py:2925, in MultiIndex.get_loc(self, key)
#    2922     return mask
#    2924 if not isinstance(key, tuple):
# -> 2925     loc = self._get_level_indexer(key, level=0)
#    2926     return _maybe_to_slice(loc)
#    2928 keylen = len(key)
#
# File ~/datascience-master/.venv/lib/python3.10/site-packages/pandas/core/indexes/multi.py:3276, in MultiIndex._get_level_indexer(self, key, level, indexer)
#    3273         return slice(i, j, step)
#    3275 else:
# -> 3276     idx = self._get_loc_single_level_index(level_index, key)
#    3278     if level > 0 or self._lexsort_depth == 0:
#    3279         # Desired level is not sorted
#    3280         if isinstance(idx, slice):
#    3281             # test_get_loc_partial_timestamp_multiindex
#
# File ~/datascience-master/.venv/lib/python3.10/site-packages/pandas/core/indexes/multi.py:2865, in MultiIndex._get_loc_single_level_index(self, level_index, key)
#    2863     return -1
#    2864 else:
# -> 2865     return level_index.get_loc(key)
#
# File ~/datascience-master/.venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'month'

# %%
date[date['date_block_num'] == 0]
# Out:
#               date  date_block_num  item_id  item_cnt_day  shop_id  day  \
# 0       02.01.2013               0    22154           1.0       59    2
# 1       03.01.2013               0     2552           1.0       25    3
# 2       05.01.2013               0     2552          -1.0       25    5
# 3       06.01.2013               0     2554           1.0       25    6
# 4       15.01.2013               0     2555           1.0       25   15
# ...            ...             ...      ...           ...      ...  ...
# 115685  19.01.2013               0       32           1.0       46   19
# 115686  18.01.2013               0       32           1.0       46   18
# 115687  26.01.2013               0       35           2.0       46   26
# 115688  31.01.2013               0      621           1.0       46   31
# 115689  07.01.2013               0       32           1.0       46    7
#
#         month  year
# 0           1  2013
# 1           1  2013
# 2           1  2013
# 3           1  2013
# 4           1  2013
# ...       ...   ...
# 115685      1  2013
# 115686      1  2013
# 115687      1  2013
# 115688      1  2013
# 115689      1  2013
#
# [115690 rows x 8 columns]

# %%
date.groupby('date_block_num')['']

# %%
date['date_cnt_month']=np.nan
date.loc[date['date_block_num']==,'Age_group']='Age_0-12'

for i in range(len(item_cnt_month)):
    date.loc[date['date_block_num']== i,'date_cnt_month']=item_cnt_month[i]

date
# Out:
#   Cell In[59], line 2
#     date.loc[date['date_block_num']==,'Age_group']='Age_0-12'
#                                      ^
# SyntaxError: invalid syntax

# %%
date
# Out:
#                date  date_block_num  item_id  item_cnt_day  shop_id  day  \
# 0        02.01.2013               0    22154           1.0       59    2
# 1        03.01.2013               0     2552           1.0       25    3
# 2        05.01.2013               0     2552          -1.0       25    5
# 3        06.01.2013               0     2554           1.0       25    6
# 4        15.01.2013               0     2555           1.0       25   15
# ...             ...             ...      ...           ...      ...  ...
# 2935844  10.10.2015              33     7409           1.0       25   10
# 2935845  09.10.2015              33     7460           1.0       25    9
# 2935846  14.10.2015              33     7459           1.0       25   14
# 2935847  22.10.2015              33     7440           1.0       25   22
# 2935848  03.10.2015              33     7460           1.0       25    3
#
#          month  year
# 0            1  2013
# 1            1  2013
# 2            1  2013
# 3            1  2013
# 4            1  2013
# ...        ...   ...
# 2935844     10  2015
# 2935845     10  2015
# 2935846     10  2015
# 2935847     10  2015
# 2935848     10  2015
#
# [2935849 rows x 8 columns]
